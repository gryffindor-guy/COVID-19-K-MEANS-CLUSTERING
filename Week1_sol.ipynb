# %% [markdown]
# <a href="https://colab.research.google.com/github/19PA1A05B3/COVID-19-K-MEANS-CLUSTERING/blob/master/Week1_sol.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **This notebook will be mainly used for the capstone project**

# %%
import pandas as pd
import numpy as np
print("Hello Capstone Project Course!")
# Out:
# Hello Capstone Project Course!
